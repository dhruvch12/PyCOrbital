# %%
import numpy as np
import matplotlib.pyplot as plt
from wrapper import get_gaussian_surface
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from wrapper import get_gaussian_surface
#
# File c:\Users\dhruv_zemanee\OneDrive\Documents\BestDataScienceProject\PyCOrbital\wrapper.py:7
#       5 # 1. Load the compiled C++ library
#       6 lib_path = os.path.join(os.path.dirname(__file__), 'core_math.dll') # Change extension based on OS
# ----> 7 c_lib = ctypes.CDLL(lib_path)
#       9 # 2. Define the exact C++ function signature for memory safety
#      10 c_lib.compute_gaussian_2d.argtypes = [
#      11     np.ctypeslib.ndpointer(dtype=np.float64, ndim=1, flags='C_CONTIGUOUS'), # x array
#      12     np.ctypeslib.ndpointer(dtype=np.float64, ndim=1, flags='C_CONTIGUOUS'), # y array
#    (...)     15     ctypes.c_double   # alpha
#      16 ]
#
# ...
